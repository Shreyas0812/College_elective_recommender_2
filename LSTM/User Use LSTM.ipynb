# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
cd /gdrive/MyDrive/Sem\ 8\ Major\ Project/Codes/LSTM/LSTM\ Saved\ Models/
# Out:
# /gdrive/MyDrive/Sem 8 Major Project/Codes/LSTM/LSTM Saved Models

# %%
ls
# Out:
# LSTM_model_sem_6_parameters_123_nrecommendations_1.h5
# LSTM_model_sem_6_parameters_134_nrecommendations_1.h5
# LSTM_model_sem_6_parameters_1_nrecommendations_1.h5

# %%
import tensorflow as tf
import numpy as np

# %%
# Recreate the exact same model, including its weights and the optimizer
model = tf.keras.models.load_model('LSTM_model_sem_6_parameters_123_nrecommendations_1.h5')

# %%
# Show the model architecture
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, 6, 5)              40
#
#  dropout_6 (Dropout)         (None, 6, 5)              0
#
#  lstm_2 (LSTM)               (None, 128)               68608
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 8)                 264
#
# ...
# Total params: 79,248
# Trainable params: 79,248
# Non-trainable params: 0
# _________________________________________________________________

# %%
yhat = model.predict([[1, 0, 1, 0, 0, 1]], verbose=0)

# %%
yhat
# Out:
# array([[0.0000000e+00, 1.6615458e-32, 2.6280612e-02, 9.6096154e-03,
#         3.5550532e-01, 4.1368026e-01, 1.8304245e-14, 1.9492424e-01]],
#       dtype=float32)

# %%
res = yhat[0]
res
# Out:
# array([0.0000000e+00, 1.6615458e-32, 2.6280612e-02, 9.6096154e-03,
#        3.5550532e-01, 4.1368026e-01, 1.8304245e-14, 1.9492424e-01],
#       dtype=float32)

# %%
indice = np.where(res == np.amax(res))
print('max value index:',indice)
 
print('max value index:',indice[0])
# Out:
# max value index: (array([5]),)
# max value index: [5]

# %%
print("Paper Recommendation: Paper", indice[0])
# Out:
# Paper Recommendation: Paper [5]

# %% [markdown]
# Reference:
# ```
# #
# def generate_seq(model, tokenizer, seq_length, seed_text, n_words):
#     result = list()
#     in_text = seed_text
#     for _ in range(n_words):
#         encoded = tokenizer.texts_to_sequences([in_text])[0]
#         encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
#         yhat = model.predict_classes(encoded, verbose=0)
#         out_word = ''
#         for word, index in tokenizer.word_index.items():
#             if index == yhat:
#                 out_word = word
#                 break
#         in_text += ' ' + out_word
#         result.append(out_word)
#     return ' '.join(result)
# print(generate_seq(model, tokenizer, 3, '1 3 5', 1))
# #Output
# # instagram
# ```

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-9034e078fa0b> in <module>()
#      14         result.append(out_word)
#      15     return ' '.join(result)
# ---> 16 print(generate_seq(model, tokenizer, 3, '1 3 5', 1))
#      17 #Output
#      18 # instagram
#
# NameError: name 'tokenizer' is not defined
